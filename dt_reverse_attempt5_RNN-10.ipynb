# %% [markdown]
# # 5th attempt - RNN

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
SIZE = 10
AMOUNT_BOARDS = 1000

# %%
gen = 2
name_df = f'{PATH_DF}\\{SIZE}-{AMOUNT_BOARDS}\\{SIZE}size_{AMOUNT_BOARDS}boards_{gen}gen_reverse'
reverse_df = pd.read_pickle(f'{name_df}.pkl')

# %%
new_columns = [f'Col_{i}' for i in range(gen*SIZE*SIZE)]
reverse_df_sort = reverse_df.sort_values(by = new_columns).reset_index(drop=True)
for i in reverse_df_sort.columns:
    reverse_df_sort[i] = reverse_df_sort[i].astype(int)

# %%
print("reverse df:", len(reverse_df))
print("reverse df sort:",len(reverse_df_sort))
# Out:
# reverse df: 41366
# reverse df sort: 41366

# %%
# Step 1: Prepare Data
amount_features = len(reverse_df_sort.columns) - SIZE*SIZE #the previous boards
features = reverse_df_sort.iloc[:, :amount_features]
name_col = 'Col_' + str(amount_features + 1)  # Target: the first pixel in the board
target = reverse_df_sort[name_col]

# Step 2: Split Data
X_train_val, X_test, y_train_val, y_test = train_test_split(features, target, test_size=0.1, random_state=365)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.1, random_state=365)

print("len x train: ", len(X_train))
print("len x test: ",len(X_test))
print("len y train: ",len(y_train))
print("len y test: ",len(y_test))
# Out:
# len x train:  33506
# len x test:  4137
# len y train:  33506
# len y test:  4137

# %%
X_train.shape
# Out:
# (33506, 100)

# %%
X_train_array = X_train.to_numpy()
y_train_array = y_train.to_numpy()

# %%
print(X_train_array.shape)
print(y_train_array.shape)
# Out:
# (33506, 100)
# (33506,)

# %%
X_train_array = X_train_array.reshape((X_train.shape[0],SIZE,SIZE,1))
y_train_array = y_train_array.reshape((y_train.shape[0],1))

# %%
print(X_train_array.shape)
print(y_train_array.shape)
# Out:
# (33506, 10, 10, 1)
# (33506, 1)

# %%
X_val_array = X_val.to_numpy()
X_val_array = X_val_array.reshape((X_val.shape[0],SIZE,SIZE,1))
y_val_array = y_val.to_numpy()
y_val_array = y_val_array.reshape((y_val.shape[0],1))

X_test_array = X_test.to_numpy()
X_test_array = X_test_array.reshape((X_test.shape[0],SIZE,SIZE,1))
y_test_array = y_test.to_numpy()
y_test_array = y_test_array.reshape((y_test.shape[0],1))

# %%
import tensorflow as tf

# הנחה: הנתונים שלך כבר בטעינה בשם:
# X_train_array: (33506, 10, 10, 1)
# y_train_array: (33506, 1)

INPUT_DIM = SIZE * SIZE  
TIMESTEPS = gen-1

# שינוי צורת הנתונים כך שתתאים ל-LSTM
X_train = X_train_array.reshape((-1, TIMESTEPS, INPUT_DIM)).astype('float32')
y_train = y_train_array.astype('float32')

print("Reshaped X_train:", X_train.shape)
print("y_train:", y_train.shape)

# הגדרת המודל
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(TIMESTEPS, INPUT_DIM)),
    tf.keras.layers.LSTM(128, activation='tanh'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # סיווג בינארי
])
# Out:
# Reshaped X_train: (33506, 1, 100)
# y_train: (33506, 1)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │       117,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 125,569 (490.50 KB)
#  Trainable params: 125,569 (490.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# אימון
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2,
    shuffle=True
)
# Out:
# Epoch 1/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.7968 - loss: 0.4596 - val_accuracy: 0.8117 - val_loss: 0.4044
# Epoch 2/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8212 - loss: 0.3783 - val_accuracy: 0.8148 - val_loss: 0.3868
# Epoch 3/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.8252 - loss: 0.3618 - val_accuracy: 0.8172 - val_loss: 0.3814
# Epoch 4/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.8456 - loss: 0.3374 - val_accuracy: 0.8271 - val_loss: 0.3669
# Epoch 5/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 13s 14ms/step - accuracy: 0.8587 - loss: 0.3092 - val_accuracy: 0.8215 - val_loss: 0.3777
# Epoch 6/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.8685 - loss: 0.2966 - val_accuracy: 0.8295 - val_loss: 0.3758
# Epoch 7/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.8813 - loss: 0.2686 - val_accuracy: 0.8253 - val_loss: 0.3948
# Epoch 8/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.8934 - loss: 0.2458 - val_accuracy: 0.8266 - val_loss: 0.4069
# Epoch 9/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9052 - loss: 0.2248 - val_accuracy: 0.8165 - val_loss: 0.4330
# Epoch 10/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9209 - loss: 0.1941 - val_accuracy: 0.8181 - val_loss: 0.4641
# Epoch 11/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9344 - loss: 0.1694 - val_accuracy: 0.8181 - val_loss: 0.5020
# Epoch 12/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9437 - loss: 0.1444 - val_accuracy: 0.8096 - val_loss: 0.5729
# Epoch 13/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9575 - loss: 0.1197 - val_accuracy: 0.8172 - val_loss: 0.6239
# Epoch 14/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 270s 320ms/step - accuracy: 0.9651 - loss: 0.0990 - val_accuracy: 0.7996 - val_loss: 0.6908
# Epoch 15/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9744 - loss: 0.0774 - val_accuracy: 0.7987 - val_loss: 0.7720
# Epoch 16/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.9799 - loss: 0.0626 - val_accuracy: 0.8072 - val_loss: 0.8516
# Epoch 17/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9849 - loss: 0.0502 - val_accuracy: 0.8132 - val_loss: 0.9424
# Epoch 18/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9889 - loss: 0.0402 - val_accuracy: 0.8021 - val_loss: 0.9760
# Epoch 19/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.9899 - loss: 0.0344 - val_accuracy: 0.8021 - val_loss: 1.1152
# Epoch 20/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9942 - loss: 0.0245 - val_accuracy: 0.8014 - val_loss: 1.1825

# %%
def evaluate_model(model, X_test_array, y_test_array):

    # predict test
    y_pred = model.predict(X_test_array)
    y_pred_binary = (y_pred > 0.5).astype(int)

    # Confusion matrix
    cm = confusion_matrix(y_test_array, y_pred_binary)
    tn, fp, fn, tp = cm.ravel()

    # calc the parameters
    precision = tp / (tp + fp + 1e-8)
    recall = tp / (tp + fn + 1e-8)
    f1 = 2 * (precision * recall) / (precision + recall + 1e-8)
    acc = (tp + tn) / (tp + tn + fp + fn)

    # print in table
    print("\n===== Evaluation Results =====")
    print("┌──────────────┬────────────┬────────────┐")
    print("│              │ Pred=Alive │ Pred=Dead  │")
    print("├──────────────┼────────────┼────────────┤")
    print(f"│ True=Alive   │ {tp:10d} │ {fn:10d} │")
    print(f"│ True=Dead    │ {fp:10d} │ {tn:10d} │")
    print("└──────────────┴────────────┴────────────┘")

    print("\n--- Performance Metrics ---")
    print(f"{'Accuracy':<12}: {acc:.3f}")
    print(f"{'Precision':<12}: {precision:.3f}")
    print(f"{'Recall':<12}: {recall:.3f}")
    print(f"{'F1-score':<12}: {f1:.3f}")

# %%
test_loss, test_acc = model.evaluate(X_test_array, y_test_array)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 test_loss, test_acc = model.evaluate(X_test_array, y_test_array)
#       2 print(f"Test accuracy: {test_acc:.3f}")
#
# File c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ValueError: Exception encountered when calling LSTMCell.call().
#
# Dimensions must be equal, but are 10 and 100 for '{{node sequential_1/lstm_1/lstm_cell_1/MatMul}} = MatMul[T=DT_FLOAT, grad_a=false, grad_b=false, transpose_a=false, transpose_b=false](sequential_1/lstm_1/strided_slice_2, sequential_1/lstm_1/lstm_cell_1/Cast/ReadVariableOp)' with input shapes: [?,10], [100,512].
#
# Arguments received by LSTMCell.call():
#   • inputs=tf.Tensor(shape=(None, 10), dtype=float32)
#   • states=('tf.Tensor(shape=(None, 128), dtype=float32)', 'tf.Tensor(shape=(None, 128), dtype=float32)')
#   • training=False

# %%
evaluate_model(model, X_test_array, y_test_array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 evaluate_model(model, X_test_array, y_test_array)
#
# Cell In[34], line 4, in evaluate_model(model, X_test_array, y_test_array)
#       1 def evaluate_model(model, X_test_array, y_test_array):
#       2
#       3     # predict test
# ----> 4     y_pred = model.predict(X_test_array)
#       5     y_pred_binary = (y_pred > 0.5).astype(int)
#       7     # Confusion matrix
#
# File c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ValueError: Exception encountered when calling LSTMCell.call().
#
# Dimensions must be equal, but are 10 and 100 for '{{node sequential_1_1/lstm_1_1/lstm_cell_1/MatMul}} = MatMul[T=DT_FLOAT, grad_a=false, grad_b=false, transpose_a=false, transpose_b=false](sequential_1_1/lstm_1_1/strided_slice_1, sequential_1_1/lstm_1_1/lstm_cell_1/Cast/ReadVariableOp)' with input shapes: [32,10], [100,512].
#
# Arguments received by LSTMCell.call():
#   • inputs=tf.Tensor(shape=(32, 10), dtype=float32)
#   • states=('tf.Tensor(shape=(32, 128), dtype=float32)', 'tf.Tensor(shape=(32, 128), dtype=float32)')
#   • training=False
