# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import import_ipynb

# %%
SIZE = 10
AMOUNT_BOARDS = 1000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 2
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE)

print("len df:", len(reverse_df_sort))
print("len train: ", len(X_train))
print("len val: ",len(X_val))
print("len test: ",len(X_test))
# Out:
# len df: 41366
# len train:  33506
# len val:  3723
# len test:  4137

# %%
model1, history1 = build_and_train_nn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8055 - loss: 0.4422 - val_accuracy: 0.8107 - val_loss: 0.3981
# Epoch 2/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8288 - loss: 0.3676 - val_accuracy: 0.8114 - val_loss: 0.3873
# Epoch 3/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8399 - loss: 0.3465 - val_accuracy: 0.8142 - val_loss: 0.3867
# Epoch 4/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8522 - loss: 0.3220 - val_accuracy: 0.8181 - val_loss: 0.3945
# Epoch 5/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8666 - loss: 0.3001 - val_accuracy: 0.8169 - val_loss: 0.4003
# Epoch 6/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8772 - loss: 0.2779 - val_accuracy: 0.8160 - val_loss: 0.4253
# Epoch 7/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8929 - loss: 0.2492 - val_accuracy: 0.8150 - val_loss: 0.4243
# Epoch 8/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9003 - loss: 0.2273 - val_accuracy: 0.8108 - val_loss: 0.4540
# Epoch 9/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9170 - loss: 0.2061 - val_accuracy: 0.8150 - val_loss: 0.4956
# Epoch 10/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9264 - loss: 0.1841 - val_accuracy: 0.8072 - val_loss: 0.5408

# %%
model2, history2 = build_and_train_cnn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.8073 - loss: 0.4400 - val_accuracy: 0.8198 - val_loss: 0.3890
# Epoch 2/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.8252 - loss: 0.3715 - val_accuracy: 0.8262 - val_loss: 0.3700
# Epoch 3/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.8462 - loss: 0.3444 - val_accuracy: 0.8329 - val_loss: 0.3679
# Epoch 4/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.8481 - loss: 0.3356 - val_accuracy: 0.8332 - val_loss: 0.3700
# Epoch 5/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8531 - loss: 0.3296 - val_accuracy: 0.8354 - val_loss: 0.3744
# Epoch 6/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8603 - loss: 0.3102 - val_accuracy: 0.8353 - val_loss: 0.3742
# Epoch 7/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8664 - loss: 0.2982 - val_accuracy: 0.8350 - val_loss: 0.4014
# Epoch 8/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8779 - loss: 0.2781 - val_accuracy: 0.8339 - val_loss: 0.4067
# Epoch 9/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8819 - loss: 0.2645 - val_accuracy: 0.8329 - val_loss: 0.4124
# Epoch 10/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8931 - loss: 0.2493 - val_accuracy: 0.8169 - val_loss: 0.4208

# %%
model3, history3 = build_and_train_rnn(X_train_array, y_train_array, SIZE, gen)
# Out:
# Epoch 1/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7970 - loss: 0.4633 - val_accuracy: 0.8105 - val_loss: 0.3988
# Epoch 2/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8220 - loss: 0.3802 - val_accuracy: 0.8151 - val_loss: 0.3895
# Epoch 3/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8319 - loss: 0.3570 - val_accuracy: 0.8232 - val_loss: 0.3790
# Epoch 4/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8498 - loss: 0.3299 - val_accuracy: 0.8263 - val_loss: 0.3804
# Epoch 5/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8607 - loss: 0.3130 - val_accuracy: 0.8245 - val_loss: 0.3835
# Epoch 6/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8737 - loss: 0.2908 - val_accuracy: 0.8286 - val_loss: 0.3850
# Epoch 7/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8826 - loss: 0.2747 - val_accuracy: 0.8223 - val_loss: 0.3974
# Epoch 8/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8974 - loss: 0.2487 - val_accuracy: 0.8248 - val_loss: 0.4071
# Epoch 9/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9090 - loss: 0.2257 - val_accuracy: 0.8208 - val_loss: 0.4391
# Epoch 10/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9175 - loss: 0.2052 - val_accuracy: 0.8201 - val_loss: 0.4665
# Epoch 11/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9293 - loss: 0.1818 - val_accuracy: 0.8199 - val_loss: 0.5022
# Epoch 12/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.9441 - loss: 0.1514 - val_accuracy: 0.8159 - val_loss: 0.5411
# Epoch 13/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 13s 14ms/step - accuracy: 0.9543 - loss: 0.1254 - val_accuracy: 0.8117 - val_loss: 0.6082
# Epoch 14/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.9644 - loss: 0.1022 - val_accuracy: 0.8199 - val_loss: 0.6409
# Epoch 15/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9736 - loss: 0.0799 - val_accuracy: 0.8111 - val_loss: 0.7533
# Epoch 16/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9802 - loss: 0.0641 - val_accuracy: 0.8132 - val_loss: 0.8150
# Epoch 17/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9838 - loss: 0.0534 - val_accuracy: 0.8138 - val_loss: 0.9050
# Epoch 18/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9888 - loss: 0.0406 - val_accuracy: 0.8087 - val_loss: 1.0161
# Epoch 19/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9908 - loss: 0.0321 - val_accuracy: 0.8126 - val_loss: 1.0786
# Epoch 20/20
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9912 - loss: 0.0279 - val_accuracy: 0.8036 - val_loss: 1.1220

# %%
X_train_array = X_train_array.reshape((X_train.shape[0],SIZE,SIZE,1))
y_train_array = y_train_array.reshape((y_train.shape[0],1))
model4, history4 = build_RCNN_sidmoind(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10)
# Out:
# X_train shape: (33505, 1, 10, 10, 1)
# y_train shape: (33505, 1)
# c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 1, 10, 10, 32)  │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1, 10, 10, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 10, 10, 64)     │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 10, 10, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │       409,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 669,697 (2.55 MB)
#  Trainable params: 669,505 (2.55 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 71s 79ms/step - accuracy: 0.8169 - loss: 0.4047 - val_accuracy: 0.8299 - val_loss: 0.3710
# Epoch 2/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 109s 111ms/step - accuracy: 0.8510 - loss: 0.3331 - val_accuracy: 0.8382 - val_loss: 0.3687
# Epoch 3/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 145s 115ms/step - accuracy: 0.8794 - loss: 0.2804 - val_accuracy: 0.8300 - val_loss: 0.3803
# Epoch 4/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 134s 105ms/step - accuracy: 0.9143 - loss: 0.2060 - val_accuracy: 0.8350 - val_loss: 0.4304
# Epoch 5/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 81s 96ms/step - accuracy: 0.9537 - loss: 0.1188 - val_accuracy: 0.8363 - val_loss: 0.6835
# Epoch 6/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 52s 62ms/step - accuracy: 0.9799 - loss: 0.0586 - val_accuracy: 0.8181 - val_loss: 0.7917
# Epoch 7/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 82s 62ms/step - accuracy: 0.9883 - loss: 0.0360 - val_accuracy: 0.8220 - val_loss: 0.9668
# Epoch 8/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 43s 51ms/step - accuracy: 0.9881 - loss: 0.0337 - val_accuracy: 0.8173 - val_loss: 0.8938
# Epoch 9/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 41s 49ms/step - accuracy: 0.9909 - loss: 0.0277 - val_accuracy: 0.8196 - val_loss: 0.8786
# Epoch 10/10
# 838/838 ━━━━━━━━━━━━━━━━━━━━ 42s 50ms/step - accuracy: 0.9911 - loss: 0.0249 - val_accuracy: 0.8223 - val_loss: 1.2467
