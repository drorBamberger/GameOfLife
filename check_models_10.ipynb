# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import import_ipynb

# %%
SIZE = 10
AMOUNT_BOARDS = 1000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 3
gen_data = gen - 1
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE,gen)

print("len df:", len(reverse_df_sort))
print("len x train: ", len(X_train_array))
print("len y train: ", len(y_train_array))
print("len x val: ",len(X_val_array))
print("len y val: ",len(y_val_array))
print("len x test: ",len(X_test_array))
print("len y test: ",len(y_test_array))
# Out:
# len df: 40470
# len x train:  32780
# len y train:  32780
# len x val:  3643
# len y val:  3643
# len x test:  4047
# len y test:  4047

# %%
model1, history1 = build_and_train_nn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 34s 17ms/step - accuracy: 0.8035 - loss: 0.4491 - val_accuracy: 0.8144 - val_loss: 0.3964
# Epoch 2/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 15s 14ms/step - accuracy: 0.8264 - loss: 0.3764 - val_accuracy: 0.8150 - val_loss: 0.3914
# Epoch 3/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8398 - loss: 0.3467 - val_accuracy: 0.8162 - val_loss: 0.3925
# Epoch 4/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.8595 - loss: 0.3094 - val_accuracy: 0.8077 - val_loss: 0.4099
# Epoch 5/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.8815 - loss: 0.2676 - val_accuracy: 0.8112 - val_loss: 0.4303
# Epoch 6/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 14s 15ms/step - accuracy: 0.9064 - loss: 0.2242 - val_accuracy: 0.7950 - val_loss: 0.4806
# Epoch 7/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.9297 - loss: 0.1784 - val_accuracy: 0.8067 - val_loss: 0.5212
# Epoch 8/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9471 - loss: 0.1394 - val_accuracy: 0.8081 - val_loss: 0.6243
# Epoch 9/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.9599 - loss: 0.1079 - val_accuracy: 0.7904 - val_loss: 0.6659
# Epoch 10/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9740 - loss: 0.0782 - val_accuracy: 0.7799 - val_loss: 0.7829

# %%
model2, history2 = build_and_train_cnn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 384/820 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.7794 - loss: 0.5077
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.7873 - loss: 0.4782 - val_accuracy: 0.8067 - val_loss: 0.4118
# Epoch 2/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.8171 - loss: 0.4006 - val_accuracy: 0.8095 - val_loss: 0.4101
# Epoch 3/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - accuracy: 0.8192 - loss: 0.3862 - val_accuracy: 0.8104 - val_loss: 0.4004
# Epoch 4/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.8321 - loss: 0.3643 - val_accuracy: 0.8122 - val_loss: 0.4138
# Epoch 5/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - accuracy: 0.8358 - loss: 0.3566 - val_accuracy: 0.8122 - val_loss: 0.3991
# Epoch 6/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.8470 - loss: 0.3404 - val_accuracy: 0.8145 - val_loss: 0.4089
# Epoch 7/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 29s 27ms/step - accuracy: 0.8526 - loss: 0.3244 - val_accuracy: 0.8092 - val_loss: 0.4120
# Epoch 8/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 54s 43ms/step - accuracy: 0.8671 - loss: 0.3048 - val_accuracy: 0.8009 - val_loss: 0.4240
# Epoch 9/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 27s 26ms/step - accuracy: 0.8698 - loss: 0.2912 - val_accuracy: 0.8113 - val_loss: 0.4759
# Epoch 10/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 35s 17ms/step - accuracy: 0.8824 - loss: 0.2698 - val_accuracy: 0.8052 - val_loss: 0.4777

# %%
model3, history3 = build_and_train_rnn(X_train_array, y_train_array, SIZE, gen)
# Out:
# Epoch 1/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 54s 22ms/step - accuracy: 0.8048 - loss: 0.4543 - val_accuracy: 0.8141 - val_loss: 0.4027
# Epoch 2/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.8259 - loss: 0.3832 - val_accuracy: 0.8121 - val_loss: 0.3874
# Epoch 3/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - accuracy: 0.8293 - loss: 0.3626 - val_accuracy: 0.8200 - val_loss: 0.3785
# Epoch 4/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - accuracy: 0.8496 - loss: 0.3271 - val_accuracy: 0.8203 - val_loss: 0.3846
# Epoch 5/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.8687 - loss: 0.2942 - val_accuracy: 0.8186 - val_loss: 0.3985
# Epoch 6/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8935 - loss: 0.2533 - val_accuracy: 0.8139 - val_loss: 0.4208
# Epoch 7/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - accuracy: 0.9118 - loss: 0.2146 - val_accuracy: 0.8099 - val_loss: 0.4673
# Epoch 8/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9353 - loss: 0.1668 - val_accuracy: 0.8080 - val_loss: 0.5500
# Epoch 9/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9557 - loss: 0.1217 - val_accuracy: 0.7985 - val_loss: 0.6619
# Epoch 10/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9739 - loss: 0.0789 - val_accuracy: 0.7973 - val_loss: 0.8240
# Epoch 11/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - accuracy: 0.9815 - loss: 0.0570 - val_accuracy: 0.8041 - val_loss: 1.0129
# Epoch 12/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - accuracy: 0.9887 - loss: 0.0369 - val_accuracy: 0.8087 - val_loss: 1.1081
# Epoch 13/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - accuracy: 0.9929 - loss: 0.0232 - val_accuracy: 0.8060 - val_loss: 1.2498
# Epoch 14/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - accuracy: 0.9921 - loss: 0.0254 - val_accuracy: 0.7918 - val_loss: 1.3306
# Epoch 15/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - accuracy: 0.9941 - loss: 0.0176 - val_accuracy: 0.7961 - val_loss: 1.4432
# Epoch 16/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - accuracy: 0.9955 - loss: 0.0141 - val_accuracy: 0.7993 - val_loss: 1.5409
# Epoch 17/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - accuracy: 0.9934 - loss: 0.0178 - val_accuracy: 0.8013 - val_loss: 1.5769
# Epoch 18/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.9953 - loss: 0.0132 - val_accuracy: 0.8005 - val_loss: 1.6206
# Epoch 19/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.9978 - loss: 0.0079 - val_accuracy: 0.7951 - val_loss: 1.6916
# Epoch 20/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.9966 - loss: 0.0107 - val_accuracy: 0.7889 - val_loss: 1.6954

# %%
model4, history4 = build_and_train_rcnn(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10,active = "sigmoid")
# Out:
# X_train shape: (32778, 4, 10, 10, 1)
# y_train shape: (32778, 1)
# c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 4, 10, 10, 32)  │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 10, 10, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 10, 10, 64)     │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 10, 10, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │       409,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 669,697 (2.55 MB)
#  Trainable params: 669,505 (2.55 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 985s 1s/step - accuracy: 0.7911 - loss: 0.4721 - val_accuracy: 0.8116 - val_loss: 0.3988
# Epoch 2/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 877s 1s/step - accuracy: 0.8301 - loss: 0.3711 - val_accuracy: 0.8214 - val_loss: 0.3798
# Epoch 3/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 853s 1s/step - accuracy: 0.8515 - loss: 0.3287 - val_accuracy: 0.8238 - val_loss: 0.3962
# Epoch 4/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 793s 966ms/step - accuracy: 0.8815 - loss: 0.2650 - val_accuracy: 0.8125 - val_loss: 0.4113
# Epoch 5/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 720s 877ms/step - accuracy: 0.9265 - loss: 0.1782 - val_accuracy: 0.8109 - val_loss: 0.5492
# Epoch 6/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 786s 930ms/step - accuracy: 0.9657 - loss: 0.0882 - val_accuracy: 0.8144 - val_loss: 0.6110
# Epoch 7/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 767s 935ms/step - accuracy: 0.9865 - loss: 0.0408 - val_accuracy: 0.8200 - val_loss: 0.8941
# Epoch 8/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 892s 1s/step - accuracy: 0.9905 - loss: 0.0264 - val_accuracy: 0.8180 - val_loss: 0.8777
# Epoch 9/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 939s 1s/step - accuracy: 0.9902 - loss: 0.0273 - val_accuracy: 0.8121 - val_loss: 1.0161
# Epoch 10/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 883s 1s/step - accuracy: 0.9926 - loss: 0.0240 - val_accuracy: 0.8180 - val_loss: 1.2510

# %%
model5, history5 = build_and_train_rcnn(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10,active = "softmax")
# Out:
# X_train shape: (32778, 4, 10, 10, 1)
# y_train shape: (32778, 2)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d_2 (ConvLSTM2D)      │ (None, 4, 10, 10, 32)  │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 4, 10, 10, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_3 (ConvLSTM2D)      │ (None, 10, 10, 64)     │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 10, 10, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │       409,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 669,762 (2.55 MB)
#  Trainable params: 669,570 (2.55 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 1020s 1s/step - accuracy: 0.7896 - loss: 0.4735 - val_accuracy: 0.8145 - val_loss: 0.3947
# Epoch 2/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 918s 1s/step - accuracy: 0.8297 - loss: 0.3717 - val_accuracy: 0.8238 - val_loss: 0.3712
# Epoch 3/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 1004s 1s/step - accuracy: 0.8500 - loss: 0.3332 - val_accuracy: 0.8311 - val_loss: 0.3826
# Epoch 4/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 1005s 1s/step - accuracy: 0.8778 - loss: 0.2852 - val_accuracy: 0.8191 - val_loss: 0.4009
# Epoch 5/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 963s 1s/step - accuracy: 0.9160 - loss: 0.2002 - val_accuracy: 0.8257 - val_loss: 0.5056
# Epoch 6/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 1022s 1s/step - accuracy: 0.9559 - loss: 0.1126 - val_accuracy: 0.8128 - val_loss: 0.5859
# Epoch 7/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 957s 1s/step - accuracy: 0.9747 - loss: 0.0662 - val_accuracy: 0.8145 - val_loss: 0.7249
# Epoch 8/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 1027s 1s/step - accuracy: 0.9827 - loss: 0.0468 - val_accuracy: 0.8206 - val_loss: 0.9400
# Epoch 9/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 1017s 1s/step - accuracy: 0.9871 - loss: 0.0351 - val_accuracy: 0.8049 - val_loss: 0.9468
# Epoch 10/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 858s 1s/step - accuracy: 0.9900 - loss: 0.0311 - val_accuracy: 0.8055 - val_loss: 1.0639

# %%
evaluate_model(model1, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        480 │        418 │
# │ True=Dead    │        419 │       2730 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.793
# Precision   : 0.534
# Recall      : 0.535
# F1-score    : 0.534

# %%
evaluate_model(model2, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        302 │        596 │
# │ True=Dead    │        239 │       2910 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.794
# Precision   : 0.558
# Recall      : 0.336
# F1-score    : 0.420

# %%
evaluate_model(model3, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        478 │        420 │
# │ True=Dead    │        414 │       2735 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.794
# Precision   : 0.536
# Recall      : 0.532
# F1-score    : 0.534

# %%
evaluate_model(model4, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 38s 262ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        417 │        480 │
# │ True=Dead    │        300 │       2848 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.807
# Precision   : 0.582
# Recall      : 0.465
# F1-score    : 0.517

# %%
evaluate_model(model5, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 40s 274ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        443 │        454 │
# │ True=Dead    │        362 │       2786 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.798
# Precision   : 0.550
# Recall      : 0.494
# F1-score    : 0.521
