# %% [markdown]
# # 3th attempt - NN

# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
SIZE = 10
AMOUNT_BOARDS = 1000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 4

# %%
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE, gen)

# %%
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE, gen)

print("len df:", len(reverse_df_sort))
print("len train: ", len(X_train))
print("len val: ",len(X_val))
print("len test: ",len(X_test))
# Out:
# len df: 39520
# len train:  32011
# len val:  3557
# len test:  3952

# %%
from functions import build_and_train_nn

model, history = build_and_train_nn(
    X_train_array,
    y_train_array,
    size=SIZE,
    dense_units=(128, 64),
    epochs=10,
    batch_size=32,
    validation_split=0.2
)

model.summary()
# Out:
# Epoch 1/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.7819 - loss: 0.4744 - val_accuracy: 0.8079 - val_loss: 0.4106
# Epoch 2/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 18s 13ms/step - accuracy: 0.8232 - loss: 0.3842 - val_accuracy: 0.8095 - val_loss: 0.4098
# Epoch 3/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.8438 - loss: 0.3417 - val_accuracy: 0.8131 - val_loss: 0.4096
# Epoch 4/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8641 - loss: 0.3016 - val_accuracy: 0.8141 - val_loss: 0.4220
# Epoch 5/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8941 - loss: 0.2473 - val_accuracy: 0.8024 - val_loss: 0.4676
# Epoch 6/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9262 - loss: 0.1854 - val_accuracy: 0.7865 - val_loss: 0.5409
# Epoch 7/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9475 - loss: 0.1389 - val_accuracy: 0.7946 - val_loss: 0.6182
# Epoch 8/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.9675 - loss: 0.0923 - val_accuracy: 0.7915 - val_loss: 0.7456
# Epoch 9/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9789 - loss: 0.0628 - val_accuracy: 0.7764 - val_loss: 0.9187
# Epoch 10/10
# 801/801 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9820 - loss: 0.0524 - val_accuracy: 0.7932 - val_loss: 0.9789
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        38,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 140,549 (549.02 KB)
#  Trainable params: 46,849 (183.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 93,700 (366.02 KB)

# %%
test_loss, test_acc = model.evaluate(X_test_array, y_test_array)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7927 - loss: 0.9617
# Test accuracy: 0.794

# %%
evaluate_model(model, X_test_array, y_test_array)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        369 │        453 │
# │ True=Dead    │        363 │       2767 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.794
# Precision   : 0.504
# Recall      : 0.449
# F1-score    : 0.475
