# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import import_ipynb

# %%
SIZE = 10
AMOUNT_BOARDS = 1000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 3
gen_data = gen - 1
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE,gen)

print("len df:", len(reverse_df_sort))
print("len x train: ", len(X_train_array))
print("len y train: ", len(y_train_array))
print("len x val: ",len(X_val_array))
print("len y val: ",len(y_val_array))
print("len x test: ",len(X_test_array))
print("len y test: ",len(y_test_array))
# Out:
# len df: 40470
# len x train:  32780
# len y train:  32780
# len x val:  3643
# len y val:  3643
# len x test:  4047
# len y test:  4047

# %%
model1, history1 = build_and_train_nn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 26s 11ms/step - accuracy: 0.7999 - loss: 0.4579 - val_accuracy: 0.8089 - val_loss: 0.3970
# Epoch 2/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.8301 - loss: 0.3725 - val_accuracy: 0.8153 - val_loss: 0.3920
# Epoch 3/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.8500 - loss: 0.3350 - val_accuracy: 0.8171 - val_loss: 0.3930
# Epoch 4/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 13s 14ms/step - accuracy: 0.8719 - loss: 0.2931 - val_accuracy: 0.8157 - val_loss: 0.4075
# Epoch 5/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.8951 - loss: 0.2485 - val_accuracy: 0.8139 - val_loss: 0.4249
# Epoch 6/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9162 - loss: 0.2073 - val_accuracy: 0.8037 - val_loss: 0.4730
# Epoch 7/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 14s 13ms/step - accuracy: 0.9372 - loss: 0.1641 - val_accuracy: 0.8067 - val_loss: 0.5455
# Epoch 8/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9525 - loss: 0.1293 - val_accuracy: 0.8054 - val_loss: 0.6162
# Epoch 9/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.9650 - loss: 0.1009 - val_accuracy: 0.7895 - val_loss: 0.7054
# Epoch 10/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9739 - loss: 0.0774 - val_accuracy: 0.7895 - val_loss: 0.7981

# %%
model2, history2 = build_and_train_cnn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 33s 20ms/step - accuracy: 0.7927 - loss: 0.4731 - val_accuracy: 0.8080 - val_loss: 0.4112
# Epoch 2/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.8138 - loss: 0.4058 - val_accuracy: 0.8131 - val_loss: 0.4091
# Epoch 3/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - accuracy: 0.8279 - loss: 0.3816 - val_accuracy: 0.8121 - val_loss: 0.4020
# Epoch 4/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 18s 16ms/step - accuracy: 0.8258 - loss: 0.3726 - val_accuracy: 0.8096 - val_loss: 0.4096
# Epoch 5/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.8334 - loss: 0.3597 - val_accuracy: 0.8090 - val_loss: 0.4027
# Epoch 6/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.8433 - loss: 0.3436 - val_accuracy: 0.8043 - val_loss: 0.4105
# Epoch 7/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.8491 - loss: 0.3307 - val_accuracy: 0.8118 - val_loss: 0.4170
# Epoch 8/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.8536 - loss: 0.3227 - val_accuracy: 0.8116 - val_loss: 0.4269
# Epoch 9/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.8589 - loss: 0.3107 - val_accuracy: 0.8115 - val_loss: 0.4409
# Epoch 10/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.8646 - loss: 0.2970 - val_accuracy: 0.8045 - val_loss: 0.4608

# %%
model3, history3 = build_and_train_rnn(X_train_array, y_train_array, SIZE, gen)
# Out:
# Epoch 1/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - accuracy: 0.7978 - loss: 0.4587 - val_accuracy: 0.8139 - val_loss: 0.4016
# Epoch 2/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.8184 - loss: 0.3867 - val_accuracy: 0.8180 - val_loss: 0.3880
# Epoch 3/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.8338 - loss: 0.3593 - val_accuracy: 0.8225 - val_loss: 0.3822
# Epoch 4/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.8490 - loss: 0.3308 - val_accuracy: 0.8215 - val_loss: 0.3855
# Epoch 5/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.8647 - loss: 0.3034 - val_accuracy: 0.8299 - val_loss: 0.3906
# Epoch 6/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - accuracy: 0.8856 - loss: 0.2658 - val_accuracy: 0.8218 - val_loss: 0.4130
# Epoch 7/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.9072 - loss: 0.2209 - val_accuracy: 0.8173 - val_loss: 0.4574
# Epoch 8/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9332 - loss: 0.1722 - val_accuracy: 0.8188 - val_loss: 0.5163
# Epoch 9/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9538 - loss: 0.1261 - val_accuracy: 0.8072 - val_loss: 0.5980
# Epoch 10/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9686 - loss: 0.0886 - val_accuracy: 0.8077 - val_loss: 0.7409
# Epoch 11/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9801 - loss: 0.0620 - val_accuracy: 0.8054 - val_loss: 0.9174
# Epoch 12/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.9872 - loss: 0.0393 - val_accuracy: 0.8048 - val_loss: 1.0640
# Epoch 13/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - accuracy: 0.9906 - loss: 0.0280 - val_accuracy: 0.8113 - val_loss: 1.1891
# Epoch 14/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9929 - loss: 0.0238 - val_accuracy: 0.7941 - val_loss: 1.2825
# Epoch 15/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9925 - loss: 0.0221 - val_accuracy: 0.8064 - val_loss: 1.3133
# Epoch 16/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9948 - loss: 0.0177 - val_accuracy: 0.8032 - val_loss: 1.3856
# Epoch 17/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9945 - loss: 0.0160 - val_accuracy: 0.8032 - val_loss: 1.4907
# Epoch 18/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9965 - loss: 0.0116 - val_accuracy: 0.8051 - val_loss: 1.5502
# Epoch 19/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9945 - loss: 0.0154 - val_accuracy: 0.8000 - val_loss: 1.5797
# Epoch 20/20
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9965 - loss: 0.0099 - val_accuracy: 0.8045 - val_loss: 1.6085

# %%
model4, history4 = build_and_train_rcnn(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10,active = "sigmoid")
# Out:
# X_train shape: (32778, 4, 10, 10, 1)
# y_train shape: (32778, 1)
# c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 4, 10, 10, 32)  │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 10, 10, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 10, 10, 64)     │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 10, 10, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │       409,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 669,697 (2.55 MB)
#  Trainable params: 669,505 (2.55 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 189s 225ms/step - accuracy: 0.7860 - loss: 0.4893 - val_accuracy: 0.8176 - val_loss: 0.3906
# Epoch 2/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 328s 400ms/step - accuracy: 0.8275 - loss: 0.3798 - val_accuracy: 0.8247 - val_loss: 0.3691
# Epoch 3/10
# 434/820 ━━━━━━━━━━━━━━━━━━━━ 6:21 987ms/step - accuracy: 0.8492 - loss: 0.3380

# %%
model5, history5 = build_and_train_rcnn(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10,active = "softmax")
# Out:
# X_train shape: (32778, 4, 10, 10, 1)
# y_train shape: (32778, 1)
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d_4 (ConvLSTM2D)      │ (None, 2, 10, 10, 32)  │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 2, 10, 10, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_5 (ConvLSTM2D)      │ (None, 10, 10, 64)     │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 10, 10, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │       409,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 669,697 (2.55 MB)
#  Trainable params: 669,505 (2.55 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/10
# c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\ops\nn.py:908: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 231s 270ms/step - accuracy: 0.2045 - loss: 0.4580 - val_accuracy: 0.2044 - val_loss: 0.3848
# Epoch 2/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 266s 274ms/step - accuracy: 0.2057 - loss: 0.3666 - val_accuracy: 0.2044 - val_loss: 0.3699
# Epoch 3/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 162s 197ms/step - accuracy: 0.2035 - loss: 0.3204 - val_accuracy: 0.2044 - val_loss: 0.4011
# Epoch 4/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 200s 244ms/step - accuracy: 0.2084 - loss: 0.2619 - val_accuracy: 0.2044 - val_loss: 0.4218
# Epoch 5/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 223s 271ms/step - accuracy: 0.2021 - loss: 0.1682 - val_accuracy: 0.2044 - val_loss: 0.4844
# Epoch 6/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 236s 287ms/step - accuracy: 0.2073 - loss: 0.0944 - val_accuracy: 0.2044 - val_loss: 0.7367
# Epoch 7/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 210s 224ms/step - accuracy: 0.2060 - loss: 0.0535 - val_accuracy: 0.2044 - val_loss: 0.7472
# Epoch 8/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 165s 202ms/step - accuracy: 0.2091 - loss: 0.0289 - val_accuracy: 0.2044 - val_loss: 0.9093
# Epoch 9/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 208s 209ms/step - accuracy: 0.2098 - loss: 0.0209 - val_accuracy: 0.2044 - val_loss: 1.1591
# Epoch 10/10
# 820/820 ━━━━━━━━━━━━━━━━━━━━ 180s 219ms/step - accuracy: 0.2051 - loss: 0.0284 - val_accuracy: 0.2044 - val_loss: 1.0563

# %%
evaluate_model(model1, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        387 │        511 │
# │ True=Dead    │        286 │       2863 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.803
# Precision   : 0.575
# Recall      : 0.431
# F1-score    : 0.493

# %%
evaluate_model(model2, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        411 │        487 │
# │ True=Dead    │        321 │       2828 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.800
# Precision   : 0.561
# Recall      : 0.458
# F1-score    : 0.504

# %%
evaluate_model(model3, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        430 │        468 │
# │ True=Dead    │        365 │       2784 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.794
# Precision   : 0.541
# Recall      : 0.479
# F1-score    : 0.508

# %%
evaluate_model(model4, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 18s 127ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        462 │        435 │
# │ True=Dead    │        346 │       2802 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.807
# Precision   : 0.572
# Recall      : 0.515
# F1-score    : 0.542

# %%
evaluate_model(model5, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
#   5/127 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 17s 132ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        897 │          0 │
# │ True=Dead    │       3148 │          0 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.222
# Precision   : 0.222
# Recall      : 1.000
# F1-score    : 0.363
