# %% [markdown]
# # 4th attempt - CNN

# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
SIZE = 10
AMOUNT_BOARDS = 1000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 4

# %%
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE, gen)

# %%
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE, gen)

print("len df:", len(reverse_df_sort))
print("len train: ", len(X_train))
print("len val: ",len(X_val))
print("len test: ",len(X_test))
# Out:
# len df: 39520
# len train:  32011
# len val:  3557
# len test:  3952

# %%
from functions import build_and_train_cnn

model, history = build_and_train_cnn(
    X_train_array,
    y_train_array,
    size=SIZE,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)

model.summary()
# Out:
# Epoch 1/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 26s 45ms/step - accuracy: 0.7905 - loss: 0.5185 - val_accuracy: 0.7871 - val_loss: 0.4613
# Epoch 2/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.7945 - loss: 0.4512 - val_accuracy: 0.7904 - val_loss: 0.4416
# Epoch 3/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.7932 - loss: 0.4356 - val_accuracy: 0.7948 - val_loss: 0.4361
# Epoch 4/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.8114 - loss: 0.4107 - val_accuracy: 0.7948 - val_loss: 0.4406
# Epoch 5/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.8199 - loss: 0.4020 - val_accuracy: 0.7979 - val_loss: 0.4405
# Epoch 6/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - accuracy: 0.8284 - loss: 0.3774 - val_accuracy: 0.7810 - val_loss: 0.4523
# Epoch 7/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.8412 - loss: 0.3611 - val_accuracy: 0.7957 - val_loss: 0.4484
# Epoch 8/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.8429 - loss: 0.3518 - val_accuracy: 0.7870 - val_loss: 0.4641
# Epoch 9/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 0.8533 - loss: 0.3325 - val_accuracy: 0.7878 - val_loss: 0.4889
# Epoch 10/10
# 201/201 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.8668 - loss: 0.3097 - val_accuracy: 0.7898 - val_loss: 0.5006
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 10, 10, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 5, 5, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 5, 5, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 107,717 (420.77 KB)
#  Trainable params: 35,905 (140.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 71,812 (280.52 KB)

# %%
test_loss, test_acc = model.evaluate(X_test_array, y_test_array)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7991 - loss: 0.4683
# Test accuracy: 0.797

# %%
results = evaluate_model(model, X_test_array, y_test_array)
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        265 │        557 │
# │ True=Dead    │        247 │       2883 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.797
# Precision   : 0.518
# Recall      : 0.322
# F1-score    : 0.397
