# %% [markdown]
# # 4th attempt - CNN

# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
SIZE = 5
AMOUNT_BOARDS = 100000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 2

# %%
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE)

print("len df:", len(reverse_df_sort))
print("len train: ", len(X_train))
print("len val: ",len(X_val))
print("len test: ",len(X_test))
# Out:
# len df: 162937
# len train:  131978
# len val:  14665
# len test:  16294

# %%
from functions import build_and_train_cnn

model, history = build_and_train_cnn(
    X_train_array,
    y_train_array,
    size=SIZE,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)

model.summary()
# Out:
# Epoch 1/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 27s 19ms/step - accuracy: 0.6522 - loss: 0.6303 - val_accuracy: 0.6690 - val_loss: 0.6068
# Epoch 2/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.6746 - loss: 0.6026 - val_accuracy: 0.6740 - val_loss: 0.6021
# Epoch 3/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - accuracy: 0.6818 - loss: 0.5966 - val_accuracy: 0.6787 - val_loss: 0.6005
# Epoch 4/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.6875 - loss: 0.5904 - val_accuracy: 0.6806 - val_loss: 0.5965
# Epoch 5/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.6878 - loss: 0.5879 - val_accuracy: 0.6848 - val_loss: 0.5947
# Epoch 6/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.6947 - loss: 0.5810 - val_accuracy: 0.6852 - val_loss: 0.5935
# Epoch 7/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.6988 - loss: 0.5764 - val_accuracy: 0.6834 - val_loss: 0.5918
# Epoch 8/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6979 - loss: 0.5769 - val_accuracy: 0.6848 - val_loss: 0.5920
# Epoch 9/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.7034 - loss: 0.5708 - val_accuracy: 0.6855 - val_loss: 0.5916
# Epoch 10/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.7060 - loss: 0.5674 - val_accuracy: 0.6875 - val_loss: 0.5928
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 5, 5, 32)       │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 2, 2, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 69,125 (270.02 KB)
#  Trainable params: 23,041 (90.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 46,084 (180.02 KB)

# %%
test_loss, test_acc = model.evaluate(X_test_array, y_test_array)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 510/510 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6867 - loss: 0.5968
# Test accuracy: 0.689

# %%
evaluate_model(model, X_test_array, y_test_array)
# Out:
# 510/510 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │       2631 │       3364 │
# │ True=Dead    │       1696 │       8603 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.689
# Precision   : 0.608
# Recall      : 0.439
# F1-score    : 0.510
