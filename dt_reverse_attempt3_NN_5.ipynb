# %% [markdown]
# # 3th attempt - NN

# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
SIZE = 5
AMOUNT_BOARDS = 10000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 2

# %%
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE)

# %%
print("len df:", len(reverse_df))
print("len train: ", len(X_train))
print("len val: ",len(X_val))
print("len test: ",len(X_test))
# Out:
# len df: 29760
# len train:  24105
# len val:  2679
# len test:  2976

# %%
from functions import build_and_train_nn

model, history = build_and_train_nn(
    X_train_array,
    y_train_array,
    size=SIZE,
    dense_units=(128, 64),
    epochs=10,
    batch_size=32,
    validation_split=0.2
)

model.summary()
# Out:
# Epoch 1/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.6629 - loss: 0.6223 - val_accuracy: 0.6797 - val_loss: 0.6021
# Epoch 2/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.6884 - loss: 0.5952 - val_accuracy: 0.6841 - val_loss: 0.5949
# Epoch 3/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7013 - loss: 0.5808 - val_accuracy: 0.6936 - val_loss: 0.5921
# Epoch 4/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.6984 - loss: 0.5779 - val_accuracy: 0.6851 - val_loss: 0.5904
# Epoch 5/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.7111 - loss: 0.5627 - val_accuracy: 0.6955 - val_loss: 0.5849
# Epoch 6/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.7142 - loss: 0.5553 - val_accuracy: 0.6982 - val_loss: 0.5841
# Epoch 7/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.7270 - loss: 0.5444 - val_accuracy: 0.6934 - val_loss: 0.5898
# Epoch 8/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7312 - loss: 0.5393 - val_accuracy: 0.6982 - val_loss: 0.5860
# Epoch 9/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.7295 - loss: 0.5343 - val_accuracy: 0.6932 - val_loss: 0.5910
# Epoch 10/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.7400 - loss: 0.5237 - val_accuracy: 0.6922 - val_loss: 0.5962
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_7 (Flatten)             │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 128)            │         3,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,949 (136.52 KB)
#  Trainable params: 11,649 (45.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 23,300 (91.02 KB)

# %%
model = attempt3_NN5(gen, X_train_array, y_train_array, SIZE, batch_size=32, epochs=3)
# Out:
# Epoch 1/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - accuracy: 0.6664 - loss: 0.6202 - val_accuracy: 0.6845 - val_loss: 0.6020
# Epoch 2/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6917 - loss: 0.5928 - val_accuracy: 0.6951 - val_loss: 0.5897
# Epoch 3/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.7007 - loss: 0.5799 - val_accuracy: 0.6938 - val_loss: 0.5849
# Epoch 4/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.7125 - loss: 0.5655 - val_accuracy: 0.6967 - val_loss: 0.5873
# Epoch 5/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7164 - loss: 0.5585 - val_accuracy: 0.6959 - val_loss: 0.5858
# Epoch 6/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.7188 - loss: 0.5561 - val_accuracy: 0.7036 - val_loss: 0.5813
# Epoch 7/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7169 - loss: 0.5522 - val_accuracy: 0.7023 - val_loss: 0.5814
# Epoch 8/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.7316 - loss: 0.5337 - val_accuracy: 0.6980 - val_loss: 0.5815
# Epoch 9/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7317 - loss: 0.5313 - val_accuracy: 0.7032 - val_loss: 0.5840
# Epoch 10/10
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.7337 - loss: 0.5255 - val_accuracy: 0.6924 - val_loss: 0.5874

# %%
test_loss, test_acc = model.evaluate(X_test_array, y_test_array)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6863 - loss: 0.5999
# Test accuracy: 0.680

# %%
evaluate_model(model, X_test_array, y_test_array)
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │        380 │        641 │
# │ True=Dead    │        310 │       1645 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.680
# Precision   : 0.551
# Recall      : 0.372
# F1-score    : 0.444
