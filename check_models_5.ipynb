# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import import_ipynb

# %%
SIZE = 5
AMOUNT_BOARDS = 1000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 3
gen_data = gen - 1
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE,gen)

print("len df:", len(reverse_df_sort))
print("len x train: ", len(X_train_array))
print("len y train: ", len(y_train_array))
print("len x val: ",len(X_val_array))
print("len y val: ",len(y_val_array))
print("len x test: ",len(X_test_array))
print("len y test: ",len(y_test_array))
# Out:
# len df: 3284
# len x train:  2659
# len y train:  2659
# len x val:  296
# len y val:  296
# len x test:  329
# len y test:  329

# %%
SIZE = 5
print('X_test_array.shape:', X_test_array.shape)
print('SIZE:', SIZE)
print('gen:', gen)
# Out:
# X_test_array.shape: (329, 5, 5, 2)
# SIZE: 5
# gen: 3

# %%
model1, history1 = build_and_train_nn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.6331 - loss: 0.6598 - val_accuracy: 0.6842 - val_loss: 0.6223
# Epoch 2/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6826 - loss: 0.6050 - val_accuracy: 0.6673 - val_loss: 0.6211
# Epoch 3/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6877 - loss: 0.5856 - val_accuracy: 0.6823 - val_loss: 0.5977
# Epoch 4/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7080 - loss: 0.5561 - val_accuracy: 0.6880 - val_loss: 0.5962
# Epoch 5/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7125 - loss: 0.5482 - val_accuracy: 0.6729 - val_loss: 0.6028
# Epoch 6/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7468 - loss: 0.5170 - val_accuracy: 0.6823 - val_loss: 0.5999
# Epoch 7/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.7573 - loss: 0.4914 - val_accuracy: 0.6936 - val_loss: 0.6083
# Epoch 8/10
# ...

# %%
model2, history2 = build_and_train_cnn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 28s 89ms/step - accuracy: 0.6442 - loss: 0.6563 - val_accuracy: 0.6786 - val_loss: 0.6242
# Epoch 2/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.6699 - loss: 0.6249 - val_accuracy: 0.6842 - val_loss: 0.6144
# Epoch 3/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.6708 - loss: 0.6078 - val_accuracy: 0.6767 - val_loss: 0.6132
# Epoch 4/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.6904 - loss: 0.5935 - val_accuracy: 0.6786 - val_loss: 0.6103
# Epoch 5/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - accuracy: 0.6968 - loss: 0.5818 - val_accuracy: 0.6955 - val_loss: 0.6060
# Epoch 6/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.7102 - loss: 0.5569 - val_accuracy: 0.6936 - val_loss: 0.6132
# Epoch 7/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7262 - loss: 0.5383 - val_accuracy: 0.6936 - val_loss: 0.6129
# Epoch 8/10
# ...

# %%
model3, history3 = build_and_train_rnn(X_train_array, y_train_array, SIZE, gen)
# Out:
# Epoch 1/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 37s 61ms/step - accuracy: 0.6337 - loss: 0.6525 - val_accuracy: 0.6786 - val_loss: 0.6218
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.6639 - loss: 0.6253 - val_accuracy: 0.6936 - val_loss: 0.5958
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6734 - loss: 0.5988 - val_accuracy: 0.7086 - val_loss: 0.5910
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.6989 - loss: 0.5816 - val_accuracy: 0.6955 - val_loss: 0.5967
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.6955 - loss: 0.5850 - val_accuracy: 0.7086 - val_loss: 0.5772
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7070 - loss: 0.5717 - val_accuracy: 0.7011 - val_loss: 0.5688
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7221 - loss: 0.5499 - val_accuracy: 0.7030 - val_loss: 0.5734
# Epoch 8/20
# ...

# %%
model4, history4 = build_and_train_rcnn(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10,active = "sigmoid")
# Out:
# X_train shape: (2657, 4, 5, 5, 1)
# y_train shape: (2657, 1)
# c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 4, 5, 5, 32)    │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 5, 5, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
model5, history5 = build_and_train_rcnn(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10,active = "softmax")
# Out:
# X_train shape: (2657, 4, 5, 5, 1)
# y_train shape: (2657, 2)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d_2 (ConvLSTM2D)      │ (None, 4, 5, 5, 32)    │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 4, 5, 5, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_3 (ConvLSTM2D)      │ (None, 5, 5, 64)       │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 5, 5, 64)       │           256 │
# ...

# %%
dec_tree_df(X_train,y_train, X_test, y_test, 10, 42)
# Out:
# (DecisionTreeClassifier(max_depth=10, random_state=42),
#  859,
#  10,
#                train      test
#  accuracy   0.902971  0.623100
#  precision  0.924528  0.473684
#  recall     0.772523  0.378151
#  f1         0.841718  0.420561)

# %%
evaluate_model(model1, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │          6 │        113 │
# │ True=Dead    │          8 │        202 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.632
# Precision   : 0.429
# Recall      : 0.050
# F1-score    : 0.090

# %%
evaluate_model(model2, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │         50 │         69 │
# │ True=Dead    │         36 │        174 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.681
# Precision   : 0.581
# Recall      : 0.420
# F1-score    : 0.488

# %%
evaluate_model(model3, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │         41 │         78 │
# │ True=Dead    │         45 │        165 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.626
# Precision   : 0.477
# Recall      : 0.345
# F1-score    : 0.400

# %%
evaluate_model(model4, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │         47 │         72 │
# │ True=Dead    │         62 │        146 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.590
# Precision   : 0.431
# Recall      : 0.395
# F1-score    : 0.412

# %%
evaluate_model(model5, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 284ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │         50 │         69 │
# │ True=Dead    │         62 │        146 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.599
# Precision   : 0.446
# Recall      : 0.420
# F1-score    : 0.433
