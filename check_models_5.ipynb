# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import import_ipynb

# %%
SIZE = 5
AMOUNT_BOARDS = 100000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 2
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE)

print("len df:", len(reverse_df_sort))
print("len train: ", len(X_train))
print("len val: ",len(X_val))
print("len test: ",len(X_test))
# Out:
# len df: 162937
# len train:  131978
# len val:  14665
# len test:  16294

# %%
model1, history1 = build_and_train_nn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - accuracy: 0.6640 - loss: 0.6175 - val_accuracy: 0.6779 - val_loss: 0.6034
# Epoch 2/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - accuracy: 0.6841 - loss: 0.5946 - val_accuracy: 0.6847 - val_loss: 0.5970
# Epoch 3/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6896 - loss: 0.5845 - val_accuracy: 0.6879 - val_loss: 0.5893
# Epoch 4/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 23s 4ms/step - accuracy: 0.6966 - loss: 0.5781 - val_accuracy: 0.6885 - val_loss: 0.5883
# Epoch 5/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 18s 5ms/step - accuracy: 0.7036 - loss: 0.5705 - val_accuracy: 0.6873 - val_loss: 0.5876
# Epoch 6/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 17s 5ms/step - accuracy: 0.7080 - loss: 0.5637 - val_accuracy: 0.6896 - val_loss: 0.5858
# Epoch 7/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 26s 7ms/step - accuracy: 0.7071 - loss: 0.5633 - val_accuracy: 0.6904 - val_loss: 0.5871
# Epoch 8/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - accuracy: 0.7124 - loss: 0.5576 - val_accuracy: 0.6924 - val_loss: 0.5831
# Epoch 9/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7156 - loss: 0.5532 - val_accuracy: 0.6939 - val_loss: 0.5844
# Epoch 10/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.7163 - loss: 0.5514 - val_accuracy: 0.6862 - val_loss: 0.5886

# %%
model2, history2 = build_and_train_cnn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 41s 9ms/step - accuracy: 0.6576 - loss: 0.6220 - val_accuracy: 0.6715 - val_loss: 0.6058
# Epoch 2/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 24s 7ms/step - accuracy: 0.6743 - loss: 0.6013 - val_accuracy: 0.6799 - val_loss: 0.5978
# Epoch 3/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - accuracy: 0.6838 - loss: 0.5935 - val_accuracy: 0.6774 - val_loss: 0.5965
# Epoch 4/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.6885 - loss: 0.5863 - val_accuracy: 0.6805 - val_loss: 0.5951
# Epoch 5/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 25s 7ms/step - accuracy: 0.6921 - loss: 0.5816 - val_accuracy: 0.6847 - val_loss: 0.5912
# Epoch 6/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 22s 7ms/step - accuracy: 0.6949 - loss: 0.5785 - val_accuracy: 0.6830 - val_loss: 0.5926
# Epoch 7/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.6997 - loss: 0.5721 - val_accuracy: 0.6851 - val_loss: 0.5982
# Epoch 8/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.7042 - loss: 0.5683 - val_accuracy: 0.6861 - val_loss: 0.5914
# Epoch 9/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 30s 9ms/step - accuracy: 0.7088 - loss: 0.5622 - val_accuracy: 0.6875 - val_loss: 0.5875
# Epoch 10/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - accuracy: 0.7074 - loss: 0.5609 - val_accuracy: 0.6840 - val_loss: 0.5915

# %%
model3, history3 = build_and_train_rnn(X_train_array, y_train_array, SIZE, gen)
# Out:
# Epoch 1/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 37s 7ms/step - accuracy: 0.6641 - loss: 0.6186 - val_accuracy: 0.6739 - val_loss: 0.6087
# Epoch 2/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 64s 13ms/step - accuracy: 0.6792 - loss: 0.6006 - val_accuracy: 0.6791 - val_loss: 0.5995
# Epoch 3/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.6840 - loss: 0.5943 - val_accuracy: 0.6846 - val_loss: 0.5952
# Epoch 4/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 30s 9ms/step - accuracy: 0.6893 - loss: 0.5858 - val_accuracy: 0.6866 - val_loss: 0.5910
# Epoch 5/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 43s 9ms/step - accuracy: 0.6974 - loss: 0.5794 - val_accuracy: 0.6915 - val_loss: 0.5842
# Epoch 6/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.7001 - loss: 0.5757 - val_accuracy: 0.6910 - val_loss: 0.5859
# Epoch 7/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 43s 13ms/step - accuracy: 0.7045 - loss: 0.5679 - val_accuracy: 0.6932 - val_loss: 0.5846
# Epoch 8/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 61s 6ms/step - accuracy: 0.7033 - loss: 0.5681 - val_accuracy: 0.6929 - val_loss: 0.5840
# Epoch 9/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 61s 12ms/step - accuracy: 0.7087 - loss: 0.5625 - val_accuracy: 0.6945 - val_loss: 0.5800
# Epoch 10/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 45s 13ms/step - accuracy: 0.7141 - loss: 0.5581 - val_accuracy: 0.6920 - val_loss: 0.5799
# Epoch 11/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 80s 13ms/step - accuracy: 0.7166 - loss: 0.5536 - val_accuracy: 0.6907 - val_loss: 0.5848
# Epoch 12/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 73s 22ms/step - accuracy: 0.7188 - loss: 0.5501 - val_accuracy: 0.6957 - val_loss: 0.5807
# Epoch 13/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 49s 15ms/step - accuracy: 0.7216 - loss: 0.5465 - val_accuracy: 0.6937 - val_loss: 0.5811
# Epoch 14/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 37s 11ms/step - accuracy: 0.7267 - loss: 0.5398 - val_accuracy: 0.6923 - val_loss: 0.5827
# Epoch 15/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.7272 - loss: 0.5397 - val_accuracy: 0.6928 - val_loss: 0.5824
# Epoch 16/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 45s 11ms/step - accuracy: 0.7309 - loss: 0.5360 - val_accuracy: 0.6957 - val_loss: 0.5841
# Epoch 17/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.7316 - loss: 0.5330 - val_accuracy: 0.6892 - val_loss: 0.5861
# Epoch 18/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 39s 12ms/step - accuracy: 0.7364 - loss: 0.5285 - val_accuracy: 0.6932 - val_loss: 0.5852
# Epoch 19/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - accuracy: 0.7344 - loss: 0.5286 - val_accuracy: 0.6895 - val_loss: 0.5899
# Epoch 20/20
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 65s 7ms/step - accuracy: 0.7391 - loss: 0.5241 - val_accuracy: 0.6915 - val_loss: 0.5948

# %%
X_train_array = X_train_array.reshape((X_train.shape[0],SIZE,SIZE,1))
y_train_array = y_train_array.reshape((y_train.shape[0],1))
model4, history4 = build_RCNN_sidmoind(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10)
# Out:
# X_train shape: (131977, 1, 5, 5, 1)
# y_train shape: (131977, 1)
# c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 1, 5, 5, 32)    │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1, 5, 5, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 5, 5, 64)       │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 5, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 362,497 (1.38 MB)
#  Trainable params: 362,305 (1.38 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 83s 23ms/step - accuracy: 0.6660 - loss: 0.6161 - val_accuracy: 0.6824 - val_loss: 0.5984
# Epoch 2/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 65s 18ms/step - accuracy: 0.6900 - loss: 0.5844 - val_accuracy: 0.6914 - val_loss: 0.5866
# Epoch 3/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 66s 20ms/step - accuracy: 0.7026 - loss: 0.5698 - val_accuracy: 0.6957 - val_loss: 0.5820
# Epoch 4/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 94s 28ms/step - accuracy: 0.7111 - loss: 0.5592 - val_accuracy: 0.6956 - val_loss: 0.5844
# Epoch 5/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 137s 27ms/step - accuracy: 0.7251 - loss: 0.5433 - val_accuracy: 0.6964 - val_loss: 0.5859
# Epoch 6/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 139s 26ms/step - accuracy: 0.7315 - loss: 0.5300 - val_accuracy: 0.6963 - val_loss: 0.6027
# Epoch 7/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 161s 32ms/step - accuracy: 0.7434 - loss: 0.5125 - val_accuracy: 0.6890 - val_loss: 0.6024
# Epoch 8/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 149s 34ms/step - accuracy: 0.7578 - loss: 0.4948 - val_accuracy: 0.6926 - val_loss: 0.6060
# Epoch 9/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 86s 26ms/step - accuracy: 0.7700 - loss: 0.4764 - val_accuracy: 0.6908 - val_loss: 0.6280
# Epoch 10/10
# 3300/3300 ━━━━━━━━━━━━━━━━━━━━ 146s 44ms/step - accuracy: 0.7812 - loss: 0.4547 - val_accuracy: 0.6852 - val_loss: 0.6356
