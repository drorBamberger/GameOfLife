# %%
# 1️⃣ ייבוא המודול והפונקציות
import functions         # ייבוא רגיל למודול
from functions import *  # ייבוא כל הפונקציות ל־namespace

# 2️⃣ טעינה מחדש
import importlib
importlib.reload(functions)  # מוודא שהמודול מעודכן

# 3️⃣ הרצת הפונקציות שוב ל־namespace
from functions import *  # שוב מייבא את כל הפונקציות אחרי ה־reload

# %%
import numpy as np
import pandas as pd
from functions import *
from read_from_file_df import *
import pickle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import import_ipynb

# %%
SIZE = 5
AMOUNT_BOARDS = 1000
AMOUNT_MOVES = 100
NUM_DICT = 1
gen = 3
gen_data = gen - 1
reverse_df_sort = load_reverse_df(SIZE, AMOUNT_BOARDS, gen)
X_train, X_val, X_test, y_train, y_val, y_test = prepare_reverse_dataset(reverse_df_sort, SIZE, gen, target_pixel_index=0, test_size=0.1, val_size=0.1, random_state=365)
X_train_array, X_val_array, X_test_array, y_train_array, y_val_array, y_test_array = to_numpy_4d(X_train, X_val, X_test, y_train, y_val, y_test, SIZE,gen)

print("len df:", len(reverse_df_sort))
print("len x train: ", len(X_train_array))
print("len y train: ", len(y_train_array))
print("len x val: ",len(X_val_array))
print("len y val: ",len(y_val_array))
print("len x test: ",len(X_test_array))
print("len y test: ",len(y_test_array))
# Out:
# len df: 3284
# len x train:  2659
# len y train:  2659
# len x val:  296
# len y val:  296
# len x test:  329
# len y test:  329

# %%
SIZE = 5
print('X_test_array.shape:', X_test_array.shape)
print('SIZE:', SIZE)
print('gen:', gen)
# Out:
# X_test_array.shape: (329, 5, 5, 2)
# SIZE: 5
# gen: 3

# %%
model1, history1 = build_and_train_nn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 16s 57ms/step - accuracy: 0.6642 - loss: 0.6525 - val_accuracy: 0.7030 - val_loss: 0.6158
# Epoch 2/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.6672 - loss: 0.6109 - val_accuracy: 0.6880 - val_loss: 0.5939
# Epoch 3/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6964 - loss: 0.5736 - val_accuracy: 0.6861 - val_loss: 0.5870
# Epoch 4/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7160 - loss: 0.5509 - val_accuracy: 0.7011 - val_loss: 0.5814
# Epoch 5/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7381 - loss: 0.5258 - val_accuracy: 0.6917 - val_loss: 0.5881
# Epoch 6/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7575 - loss: 0.5119 - val_accuracy: 0.7030 - val_loss: 0.5799
# Epoch 7/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7818 - loss: 0.4720 - val_accuracy: 0.6805 - val_loss: 0.5996
# Epoch 8/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7875 - loss: 0.4588 - val_accuracy: 0.6823 - val_loss: 0.6044
# Epoch 9/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8119 - loss: 0.4197 - val_accuracy: 0.6936 - val_loss: 0.6208
# Epoch 10/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8436 - loss: 0.3777 - val_accuracy: 0.6673 - val_loss: 0.6511

# %%
model2, history2 = build_and_train_cnn(X_train_array, y_train_array, SIZE)
# Out:
# Epoch 1/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 16s 58ms/step - accuracy: 0.6435 - loss: 0.6567 - val_accuracy: 0.6786 - val_loss: 0.6268
# Epoch 2/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.6627 - loss: 0.6349 - val_accuracy: 0.6786 - val_loss: 0.6178
# Epoch 3/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6745 - loss: 0.6128 - val_accuracy: 0.6711 - val_loss: 0.6142
# Epoch 4/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.6832 - loss: 0.5975 - val_accuracy: 0.6391 - val_loss: 0.6209
# Epoch 5/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7109 - loss: 0.5787 - val_accuracy: 0.6805 - val_loss: 0.6166
# Epoch 6/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7092 - loss: 0.5565 - val_accuracy: 0.6861 - val_loss: 0.6030
# Epoch 7/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7245 - loss: 0.5358 - val_accuracy: 0.6748 - val_loss: 0.6043
# Epoch 8/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7424 - loss: 0.5165 - val_accuracy: 0.6880 - val_loss: 0.6083
# Epoch 9/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7716 - loss: 0.4870 - val_accuracy: 0.6861 - val_loss: 0.6311
# Epoch 10/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7780 - loss: 0.4669 - val_accuracy: 0.6353 - val_loss: 0.6710

# %%
model3, history3 = build_and_train_rnn(X_train_array, y_train_array, SIZE, gen)
# Out:
# Epoch 1/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 17s 47ms/step - accuracy: 0.6343 - loss: 0.6588 - val_accuracy: 0.6786 - val_loss: 0.6173
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6598 - loss: 0.6262 - val_accuracy: 0.6936 - val_loss: 0.5958
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6857 - loss: 0.5974 - val_accuracy: 0.6974 - val_loss: 0.5891
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6876 - loss: 0.5886 - val_accuracy: 0.7011 - val_loss: 0.5826
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6812 - loss: 0.5874 - val_accuracy: 0.6955 - val_loss: 0.5810
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6940 - loss: 0.5691 - val_accuracy: 0.6974 - val_loss: 0.5761
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.7093 - loss: 0.5613 - val_accuracy: 0.6805 - val_loss: 0.5905
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6949 - loss: 0.5598 - val_accuracy: 0.6898 - val_loss: 0.5859
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7209 - loss: 0.5503 - val_accuracy: 0.6936 - val_loss: 0.5843
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7302 - loss: 0.5228 - val_accuracy: 0.6861 - val_loss: 0.5897
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.7490 - loss: 0.5111 - val_accuracy: 0.6805 - val_loss: 0.5964
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7519 - loss: 0.4954 - val_accuracy: 0.6805 - val_loss: 0.6017
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7714 - loss: 0.4758 - val_accuracy: 0.6898 - val_loss: 0.5951
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7771 - loss: 0.4650 - val_accuracy: 0.6635 - val_loss: 0.6245
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7972 - loss: 0.4347 - val_accuracy: 0.6429 - val_loss: 0.6336
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8200 - loss: 0.4081 - val_accuracy: 0.6485 - val_loss: 0.6748
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.8236 - loss: 0.3958 - val_accuracy: 0.6729 - val_loss: 0.6701
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8497 - loss: 0.3623 - val_accuracy: 0.6692 - val_loss: 0.7039
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8515 - loss: 0.3511 - val_accuracy: 0.6485 - val_loss: 0.7209
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8761 - loss: 0.2994 - val_accuracy: 0.6635 - val_loss: 0.7459

# %%
model4, history4 = build_and_train_rcnn(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10,active = "sigmoid")
# Out:
# X_train shape: (2657, 4, 5, 5, 1)
# y_train shape: (2657, 1)
# c:\Users\דרור\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 4, 5, 5, 32)    │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 5, 5, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 5, 5, 64)       │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 5, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 362,497 (1.38 MB)
#  Trainable params: 362,305 (1.38 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 85s 422ms/step - accuracy: 0.6096 - loss: 0.7725 - val_accuracy: 0.6786 - val_loss: 0.6914
# Epoch 2/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 31s 456ms/step - accuracy: 0.6925 - loss: 0.5996 - val_accuracy: 0.6673 - val_loss: 0.6923
# Epoch 3/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 30s 442ms/step - accuracy: 0.7153 - loss: 0.5439 - val_accuracy: 0.3214 - val_loss: 0.7030
# Epoch 4/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 40s 424ms/step - accuracy: 0.7760 - loss: 0.4862 - val_accuracy: 0.3214 - val_loss: 0.7245
# Epoch 5/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 24s 361ms/step - accuracy: 0.8186 - loss: 0.4130 - val_accuracy: 0.3214 - val_loss: 0.7385
# Epoch 6/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 35s 252ms/step - accuracy: 0.8804 - loss: 0.3079 - val_accuracy: 0.3233 - val_loss: 0.8244
# Epoch 7/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 35s 460ms/step - accuracy: 0.9534 - loss: 0.1734 - val_accuracy: 0.3647 - val_loss: 0.8407
# Epoch 8/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 38s 404ms/step - accuracy: 0.9820 - loss: 0.1025 - val_accuracy: 0.5150 - val_loss: 0.7917
# Epoch 9/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 24s 357ms/step - accuracy: 0.9913 - loss: 0.0626 - val_accuracy: 0.5695 - val_loss: 0.7903
# Epoch 10/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 32s 482ms/step - accuracy: 0.9969 - loss: 0.0302 - val_accuracy: 0.6015 - val_loss: 0.9084

# %%
model5, history5 = build_and_train_rcnn(gen, X_train_array, y_train_array, SIZE, batch_size = 32, epochs = 10,active = "softmax")
# Out:
# X_train shape: (2657, 4, 5, 5, 1)
# y_train shape: (2657, 2)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv_lstm2d_2 (ConvLSTM2D)      │ (None, 4, 5, 5, 32)    │        38,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 4, 5, 5, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_3 (ConvLSTM2D)      │ (None, 5, 5, 64)       │       221,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 5, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │       102,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 362,562 (1.38 MB)
#  Trainable params: 362,370 (1.38 MB)
#  Non-trainable params: 192 (768.00 B)
# Epoch 1/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 94s 507ms/step - accuracy: 0.6089 - loss: 0.7776 - val_accuracy: 0.6786 - val_loss: 0.6843
# Epoch 2/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 22s 316ms/step - accuracy: 0.6784 - loss: 0.6034 - val_accuracy: 0.6786 - val_loss: 0.6813
# Epoch 3/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 29s 424ms/step - accuracy: 0.6962 - loss: 0.5588 - val_accuracy: 0.6786 - val_loss: 0.6730
# Epoch 4/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 41s 412ms/step - accuracy: 0.7383 - loss: 0.5082 - val_accuracy: 0.5207 - val_loss: 0.6930
# Epoch 5/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 50s 544ms/step - accuracy: 0.8292 - loss: 0.4133 - val_accuracy: 0.3214 - val_loss: 0.7410
# Epoch 6/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 38s 499ms/step - accuracy: 0.8961 - loss: 0.2891 - val_accuracy: 0.4718 - val_loss: 0.7162
# Epoch 7/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 17s 256ms/step - accuracy: 0.9292 - loss: 0.2001 - val_accuracy: 0.5620 - val_loss: 0.7014
# Epoch 8/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 23s 280ms/step - accuracy: 0.9738 - loss: 0.1082 - val_accuracy: 0.6015 - val_loss: 0.6841
# Epoch 9/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 24s 322ms/step - accuracy: 0.9854 - loss: 0.0620 - val_accuracy: 0.6429 - val_loss: 0.7527
# Epoch 10/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 29s 427ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.6147 - val_loss: 0.9103

# %%
dec_tree_df(X_train,y_train, X_test, y_test, 10, 42)
# Out:
# (DecisionTreeClassifier(max_depth=10, random_state=42),
#  859,
#  10,
#                train      test
#  accuracy   0.902971  0.623100
#  precision  0.924528  0.473684
#  recall     0.772523  0.378151
#  f1         0.841718  0.420561)

# %%
evaluate_model(model1, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │         54 │         65 │
# │ True=Dead    │         59 │        151 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.623
# Precision   : 0.478
# Recall      : 0.454
# F1-score    : 0.466

# %%
evaluate_model(model2, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │         48 │         71 │
# │ True=Dead    │         54 │        156 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.620
# Precision   : 0.471
# Recall      : 0.403
# F1-score    : 0.434

# %%
evaluate_model(model3, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 227ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │         34 │         85 │
# │ True=Dead    │         40 │        170 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.620
# Precision   : 0.459
# Recall      : 0.286
# F1-score    : 0.352

# %%
evaluate_model(model4, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 13s 632ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │         65 │         54 │
# │ True=Dead    │         77 │        131 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.599
# Precision   : 0.458
# Recall      : 0.546
# F1-score    : 0.498

# %%
evaluate_model(model5, X_test_array, y_test_array, size=SIZE, gen=gen)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 824ms/step
#
# ===== Evaluation Results =====
# ┌──────────────┬────────────┬────────────┐
# │              │ Pred=Alive │ Pred=Dead  │
# ├──────────────┼────────────┼────────────┤
# │ True=Alive   │         52 │         67 │
# │ True=Dead    │         67 │        141 │
# └──────────────┴────────────┴────────────┘
#
# --- Performance Metrics ---
# Accuracy    : 0.590
# Precision   : 0.437
# Recall      : 0.437
# F1-score    : 0.437
